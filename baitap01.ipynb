# %%
import random

# %%
df = []

# %%
for i in range(1000):
    i = random.uniform(0, 1)
    df.append(i)
print(df)
# Out:
# [0.6413256660334968, 0.9076447070169016, 0.8085895886564004, 0.28106348030766315, 0.613935509346566, 0.9180952464119203, 0.7600700549549319, 0.2961780171011196, 0.37589204763061435, 0.4942408115860507, 0.0985200262618533, 0.1489503547908284, 0.23536907129107643, 0.340986499933016, 0.008397442679392797, 0.7566402069840241, 0.63006059427947, 0.1686486777617906, 0.7884171402019621, 0.4599992498375165, 0.4538205921864247, 0.5397528531039637, 0.7254741959712193, 0.6676752872010902, 0.1871608142061838, 0.6994352025496113, 0.15235691210054647, 0.576099660760903, 0.5949090241224008, 0.8770339580197368, 0.9605658692758203, 0.6937157897363809, 0.7118059948991932, 0.3422156912508262, 0.3538948580758231, 0.8674098881564379, 0.06748542329462537, 0.29799133852135573, 0.3519983918298737, 0.9988275192133469, 0.18569484570466566, 0.0996648160408774, 0.24807288267542638, 0.8489665431374257, 0.3879083263217248, 0.9078781441974269, 0.5656566750086988, 0.47557187198601114, 0.2479723680431376, 0.182864115
# ...

# %%
firstRdd = sc.parallelize(df)

# %%
sum = firstRdd.reduce(lambda x, y: x + y)

# %%
count = firstRdd.count()

# %%
print("Trung binh cong cua 1000 so thuc: ", sum/count)
# Out:
# Trung binh cong cua 1000 so thuc:  0.5011929158314007

# %%
multiply = firstRdd.reduce(lambda x, y: x * y)

# %%
print("Trung binh nhan cua 1000 so thuc: ", multiply/count)
# Out:
# Trung binh nhan cua 1000 so thuc:  0.0
